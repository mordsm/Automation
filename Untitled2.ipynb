# %%
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter
import io

resource_manager = PDFResourceManager()
fake_file_handle = io.StringIO()
converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())
page_interpreter = PDFPageInterpreter(resource_manager, converter)

with open('/home/moshe/workspace/projects/Automation/mail_server/electric_bill/2020-471639834_20201112_174309.pdf', 'rb') as fh:

    for page in PDFPage.get_pages(fh,
                                  caching=True,
                                  check_extractable=True):
        page_interpreter.process_page(page)

    text = fake_file_handle.getvalue()

# close open handles
converter.close()
fake_file_handle.close()

print(text)
# Out:
# מ"עב לארשיל למשחה תרבח
#
#
# 2020-471639834 רוקמ - הלבק/סמ תינובשח
# 520000472 הרבח רפסמ
# 558418570 'סמ םיקסוע דוחיאב חוודמ
# הפיח ,1 רואה ביתנ
# 340344708  :הזוח ןובשח רפסמ
# םימי  57 - הפוקתל  ןובשח
# 11/11/2020  דע 16/09/2020 -מ
#
# ןובשחה תכירע ךיראת
# 12/11/2020
#
#
#
#
# :הממיב תועש 24 ,ךתורישל
# הרבחה לש טנרטניאה רתא
#   www.iec.co.il
# רוסמל ,ןובשחה תא םלשל ןתינ וב
# .םינוש םיאשונב עדימ לבקלו הנומ בצמ
#
# 103 תוריש
# םיתוריש תלבקל ,תולקת לע חווידל
# :תונכרצו תונובשח יאשונב
# 103 - ירלולסו יווק ןופלט
# 1800-200-103 סקפ
#
# .םניח – ןופלט לכמ 103 דקומל תוחישה
# הז ןובשח םלשל ןיא
#
#
#
# בויחל חלשיי ךנובשח
# .02/12/2020 -ב
# יארשא סיטרכב
# .2964 תורפסב םייתסמה
#
# ט
# ל
# "
# ח
#
# 1,127.28
# 1.69
# 35.10
# -0.91
# 1,163.16
# 197.74
# 1,360.90
#
# :דובכל
# ןורש השמ
# 6 ד 7 דוד רזעלא
# 5403207 לאומש תעבג
#
#
# 046-560-010
#
# א"ת 56 ץיבלינא :הרזחהל
#
#
# ןובשחה זוכיר
# ש"טוק 2514 כ"הס - הכירצ ןיגב בויח
# (KVA) קפסה ןיגב םולשת
# עובק םולשת
# םינוש םייוכיזו םיבויח
# מ"עמ אלל כ"הס
# 17.00 % מ"עמ
# ןובשח תפוקתל מ"עמ ללוכ כ"הס
#
# 1
# 0
# 0
# 0
# 0
# -
# 0
# 1
# 3
# 4
# 7
# 1
# _
# 2
# 1
# 1
# 1
# 0
# 2
# 0
# 2
# _
# 1
# 0
# 0
# 0
# B
# X
#
# 1,360.90
#
# (ח"ש) םולשתל כ"הס
#
# ךלש למשחה תכירצ
# ךירוגמ ריעב תעצוממה הכירצה תמועל
#
#  !!! םכבל תמושתל
#  .₪ 10,000 לעמ םימוכס םג יארשא סיטרכב םלשל ןתינ תעכ
# הלמעב ביוחי ₪ 10,000 לעמ יארשא סיטרכב םולשת
# .(10,000 לעמ הנושארה הרוגאהמ לחה) ₪ 1,000 לכל ₪ 8 לש
#
# תועדוה
# ■
#
# ש"טוק
# 2,700
#
# 2,160
#
# 1,620
#
# 1,080
#
# 540
#
# 0
#
# טפס
# 19
#
# קוא
# 19
#
# בונ
# 19
#
# מצד
# 19
#
# וני
# 20
#
# רבפ
# 20
#
# ץרמ
# 20
#
# רפא
# 20
#
# יאמ
# 20
#
# נוי
# 20
#
# לוי
# 20
#
# גוא
# 20
#
# טפס
# 20
#
# קוא
# 20
#
# דיחא
#
# ..................................................................................................................................................................
#
#
#
# 2020-471639834                           יוכיז תעדוה / רבוש
# :הזוח ןובשח רפסמ
# 340344708
# 1,360.90
# םולשתל אל
#
# הז ןובשח םלשל ןיא
#
# הפוקתל ןובשח
# 11/11/2020 דע 16/09/2020-מ
#
# :ןכרצה םש
# ןורש השמ
#
# ח"שב םולשתל םוכסה
#
# עבק תארוה יפ לע ןובשחה בויח
#
# 2964 בויחל יארשא סיטרכ רפסמ
#
# ריחמ
#
# ש"טוקל
# תורוגאב
# 44.84
#
# ח"שב כ"הס
#
# 1127.28
# 1127.28
# 1127.28
#
# הכירצ
# ש"טוקב
#
# האירק
# תמדוק
#
# האירק
# תיחכונ
#
# 35123
#
# 37637
#
# 2514
# 2514
# 2514
#
# םייוכיזה / םיבויחה טוריפ
# 340344708  :הזוח ןובשח רפסמ
# 11/11/2020 דע 16/09/2020 -מ הפוקתל ןובשח
#
# ןורש השמ
#
# (מ"עמ ללוכ אל) י"חחמ הכירצ ןיגב בויח
# 1 :הלפכה םרוג 7085267 רפסמ הנומ תואירק
# ףירעת
#
# האירק גוס
#
# םימי
# בויחל
#
# האירק יכיראת
# תיחכונ
# תמדוק
# םוי/שדוח
# םוי/שדוח
# 11/11
# 57 15/09
#
# תיחכונ
#
# הליגר
#
# יתיב
# כ"הס
# הכירצ ןיגב כ"הס
# (מ"עמ ללוכ אל) (KVA) קפסה ןיגב םולשת
#
# (רפמא 25 רוביח לדוג) KVA 5.75 קפסה
# KVA 1 לכל הנשל ח"ש 1.89 יפל םימי 57 , 11/11/2020 דע 16/09/2020 הפוקתל
# כ"הס
#
# .יתנש סיסב לע ימוי ןפואב בשוחמ קפסה ןיגב םולשת ■
# (מ"עמ ללוכ אל) עובק םולשת
#
# 7.85 יפל םימי 57 ,11/11/2020 - 16/09/2020 הפוקתל הקולח עובק םולשת
# 10.93 יפל םימי 57 ,11/11/2020 - 16/09/2020 הפוקתל הקפסא עובק םולשת
# כ"הס
#
# דומע
# 2/6
#
# ח"ש
#
# ח"ש
# ח"ש
#
# ח"ש
# ח"ש
# ח"ש
#
# 1.69
# 1.69
#
# 14.67
# 20.43
# 35.10
#
# 2
# 0
# 0
# 0
# 0
# -
# 2
# 1
# 3
# 4
# 7
# 1
# _
# 2
# 1
# 1
# 1
# 0
# 2
# 0
# 2
# _
# 1
# 0
# 0
# 0
# B
# X
#
# םולשתלו ,הקולח עובק ישדוח םולשתל הדרפהב םיגצומ םהו ,םיעובקה םיישדוחה םימולשתה ונכדוע ,תושרה תטלחה יפל
# .הקפסא עובק ישדוח
#
# .םולשתה יביכר םוכס ןיבל (םולשתל עבוקה םוכסה אוהש) עובקה ישדוחה םולשתה כ"הס ןיב רעפ ןכתיי ,םימוכס לוגיע לשב ■
# :עובקה םולשתה יביכרמ טוריפ ןלהל
# חוקלה גוס ישדוח םולשת
# הקולח – עובק
#
# הנומ תאירק
#
# הקולח כ"הס תוחוקל תוריש
# ןכרצל עדימו
# 1.93
#
# 7.85
#
# לועפתו ןוה
# םינומה
# 3.99
#
# 1.92
#
# יזאפ דח - דיחא ףירעת
#
# .יתנש סיסב לע ימוי ןפואב בשוחמ עובק םולשת ■
# ■
#
# הקפסא כ"הס תוחוקל תוריש
# ןכרצל עדימו
# 4.61
#
# 10.93
#
# הייבג ןובשח תכירע
# חולשמו
# 1.63
#
# 4.69
#
# ח"ש
# ח"ש
#
# -0.91
# -0.91
#
# חוקלה גוס ישדוח םולשת
# הקפסא – עובק
#
# יזאפ דח - דיחא ףירעת
#
# (מ"עמ ללוכ אל) םינוש םייוכיזו םיבויח
#
# ינורטקלא ראודב ןובשחה תלבק ןיגב יוכיז
# כ"הס
#
# עיפומה דחואמה קסועה רפסמ תא ןייצל שי ,למשחה תרבח םע ךיתואקסע לע מ"עמל חוודל שרדנ ךנהו הדימב ,דבכנ חוקל
# ןובשחה תישארב
#
# 11/10/2020 - ב יארשאה תרבחב היבגל חלשנ ח"ש 1,736.85 ךסב 09/2020 ן-ח ■
#
# תויללכ תועדוה
# ■
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# תושר ידי לע םיעבקנ ,למשחה תרבחו ןכרצה תובוח/תויוכז תא תוטרפמה הדימה תומאו םינושה םיבויחה ,למשחה יפירעת
# :םיאבה םירתאב ןכו ,למשחה תרבח ידרשמב אוצמל ןתינ ,הדימה תומאו םינושה םיפירעתה לע עדימ .למשחה
# http://www.iec.co.il
# https://www.gov.il/he/departments/the_electricity_authority
#  :תבותכב הרבחה לש טנרטניאה רתאב לבקל ןתינ תוליעפה תועשו םיתורישה ,תורישה יזכרמ לע עדימ
# https://www.iec.co.il/pages/servicecenters.aspx
#
# ■
#
# תויללכ תועדוה
# ■
#
# דומע
# 3/6
#
# 3
# 0
# 0
# 0
# 0
# -
# 2
# 1
# 3
# 4
# 7
# 1
# _
# 2
# 1
# 1
# 1
# 0
# 2
# 0
# 2
# _
# 1
# 0
# 0
# 0
# B
# X
#
# תא רוגסת חור שי ןולחה!תיארונ?המל האימחמ אקווד איהתירולבל ילתא םירבועםימיענב ףרוחה ףרוחל ךרעיהל דציכ תעדל םיצור?רתויב הבוטה הרוצב!דואמ טושפ הזדומע
# 4/6
#
# 4
# 0
# 0
# 0
# 0
# -
# 2
# 1
# 3
# 4
# 7
# 1
# _
# 2
# 1
# 1
# 1
# 0
# 2
# 0
# 2
# _
# 1
# 0
# 0
# 0
# B
# X
#
#   ?ףרוחל וכרעית דציכ םיסירת :חורב ףועל לולעש המ לכ םיעבקמו םיקזחמ וא םינפמ .םיציצעו תוינדא ,שמש ידודו םיטלוק ,םיפפור םיקדובו ,קבאמ רונתה תאו )םירטליפ( ןגזמה יננסמ תא םיקנמ!םוגפ למשח רישכמב שמתשהל רוסא :ורכז .םתוניקת תא שי .הרידסה למשחה תקספהב םישוביש ונכתיי ,הרעס תעב םיניכמ :ןתארקל ךרעיהל בושח לבא ,עונמל רשפא יאש תולקת ןעטמ ,םוריח תרואת ,תוללוס ,םימח םידגבו תוכימש שיגנ םוקמב.םישיגר םייאופר םירישכמל יוביגכ הנימז הללוסו ירלולסל דיינ?יתוחיטבו ליעי יכה ןפואב תיבה תא וממחת דציכ )A( הובג יטגרנא גוריד םע םגדב ורחב ?ןגזמ םישכור .רתויב ליעיהו חוטבה םומיחה יעצמא אוה ןגזמה.תובר םינשל למשחה תואצוהב וכסיחו.ןגזמה לש למשחה תכירצל 5% הפיסומ תפסונ הלעמ לכ !םיענו םח הז – תולעמ 20-ל ןגזמה תא ונווכ וא רוטקבנוק ומכ ,טטסומרת םעו חוטב ,ינוכסח םומיח רישכמ קר הפולחכ ורחב ?ןגזמב םומיח םיבהוא אל.רוטאידר!ןכוסמו ליעי אל ,רקי הז :הלריפס רונתב שומישמ וענמיה.םיקילד םירמוחו םיצפח ונממ וקיחרהו ,םיבוטר םידגב וילע וחינת לא !שוביי ןקתמ וניא םומיח רונת וא קלד רונתב הקסה תעב( תיבב םוחה לע הרימשל תותלדו תונולח ורגס ?ילמשח םומיח רישכמ םיליעפמ)!רורוויא ךרוצל חתפ לע ורמש ,םיצע?למשח תקספה לש הרקמב םישוע המ ןכתי .םכלצא איה היעבה ,למשח שי םינכשל םא ?רוזאה לכב וא םכתרידב קר איה הקספהה םאה קספמ תא ומירהו ,הנורחאל םתלעפהש רישכמה תא למשחהמ וקתנ ?ןיקת אל ילמשח רישכמ םתלעפהש.ופילחהל וא ונקתל שיו ,רישכמב היעבה ?רזח למשחה .למשחה חולב ןגמה יאלמשח םע וצעייתה – קיפסמ וניא רוביחה לדוג ילוא ?םירישכמ רפסמ םיליעפמ רשאכ ץפוק קספמה!השרומ למשחה תרבח רתאב וא היצקילפאב וקדב .ךרדב םיאנכטהו הנכדוע רבכ למשחה תרבח ?ךושח בוחרה לכ.הב לופיטה בצמ המו ,)תודובע ךרוצל המוזי הקספה שיש וא( םכרוזאב הלקת החווד םא הקיפסמ ןכלו ,תובר תוינפ ונילא תועיגמ הלקת תעב .103 וגייח וא היצקילפאב וחווד ?העיפומ הניא הלקתה!בושו בוש רשקתהל ךרוצ ןיא .ירשפאה םדקהב לפוטת רשא תחא העדוה?הניקת םכתרידב הקראהה םאה לש הרקמב ןה ,ןיינבב םיאצמנה דויצו םדא ינבב העיגפ עונמל הדעונ הקראה :םייח הליצמ הניקת הקראה .םיקרב דגנ ןהו תולמשחתה ונבנש תורידבו ,םינש 10-ב םעפ תוחפל הקראהה תא קודבל שי ?הנורחאה םעפב הקראהה תא םתקדב יתמ.םינש 5-ל תחא - 1979 ינפל .השרומ יאלמשח ונימזה ,םיחוטב םכניא םאדומע
# 5/6
#
# 5
# 0
# 0
# 0
# 0
# -
# 2
# 1
# 3
# 4
# 7
# 1
# _
# 2
# 1
# 1
# 1
# 0
# 2
# 0
# 2
# _
# 1
# 0
# 0
# 0
# B
# X
#
#  למשחב חוטבו ינוכסח ,ליעי שומיש לע ףסונ עדימלמשחה תרבח רתאבו היצקילפאב?למשחב רושקה יתוחיטב עגפמב םתלקתנ וסרקש םיצע ,לפנש למשח דומע ,עורק למשח לבכ םתיאר?רחא ןכוסמ עגפמ וא למשחה יטוח לע.103 וגייחו םלוכ תא וקיחרה ,םוקמהמ וקחרתה!היצקילפאבו למשחה תרבח רתאב םג חוודל רשפא2020  רבמבונ  ,למשחה תרבח - היצלוגרו  קוויש , תוריש תביטח ,תיקוויש תרושקת ׳חמ :בוציע

# %%
pip install pdfminer3
# Out:
# Collecting pdfminer3
#   Downloading https://files.pythonhosted.org/packages/68/d4/81ce4f7ca0c563da98283501747af8248de5021aeaa4c69c9ae460e13efb/pdfminer3-2018.12.3.0.tar.gz (5.0MB)
#      |████████████████████████████████| 5.0MB 865kB/s eta 0:00:01     |█████████▎                      | 1.5MB 865kB/s eta 0:00:05
# Collecting pycryptodome (from pdfminer3)
#   Using cached https://files.pythonhosted.org/packages/aa/36/f97c4b16619618e169b9e0d687eab78868c7474ff8c1ec6f584a8b10b29b/pycryptodome-3.9.9-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied: sortedcontainers in /home/moshe/anaconda3/lib/python3.7/site-packages (from pdfminer3) (2.1.0)
# Requirement already satisfied: chardet in /home/moshe/.local/lib/python3.7/site-packages (from pdfminer3) (3.0.4)
# Building wheels for collected packages: pdfminer3
#   Building wheel for pdfminer3 (setup.py) ... done
#   Stored in directory: /home/moshe/.cache/pip/wheels/27/35/61/7d4c0c350683751100186de869681db04d6f2c5ab603eb0510
# Successfully built pdfminer3
# Installing collected packages: pycryptodome, pdfminer3
# ERROR: Could not install packages due to an EnvironmentError: [Errno 13] Permission denied: '/home/moshe/anaconda3/bin/__pycache__/pdf2txt.cpython-37.pyc'
# Consider using the `--user` option or check the permissions.
#
# Note: you may need to restart the kernel to use updated packages.
