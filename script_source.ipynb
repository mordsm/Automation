# %%
data={
   "id":"de7ee181-167a-4939-95e8-11d0834b5d42",
   "version":"2.0",
   "name":"bp_test",
   "url":"https://www.bankhapoalim.co.il",
   "tests":[
      {
         "id":"f68bf018-e58a-41ca-87e9-6583d1fd3aa4",
         "name":"bp_test",
         "commands":[
            {
               "id":"c153076a-8beb-499c-ade7-89837b664130",
               "comment":"",
               "command":"open",
               "target":"/he/login",
               "targets":[
                  
               ],
               "value":"",
               "name":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"b664752e-9eaf-4c2c-b946-e813561b79aa",
               "comment":"",
               "command":"setWindowSize",
               "target":"1717x453",
               "targets":[
                  
               ],
               "value":"",
               "name":"",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"496273d4-f96e-4765-abdc-4b0c11999e4e",
               "comment":"",
               "command":"click",
               "target":"css=.login-button > .desktop",
               "targets":[
                  [
                     "css=.login-button > .desktop",
                     "css:finder"
                  ],
                  [
                     "xpath=//li[2]/a/span",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05df",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"3d9d1a8e-576e-4c77-8339-44c909f91943",
               "comment":"",
               "command":"selectFrame",
               "target":"index=0",
               "targets":[
                  [
                     "index=0"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"82e1ebf4-0f4f-4d27-9299-a188f6305856",
               "comment":"",
               "command":"click",
               "target":"id=userCode",
               "targets":[
                  [
                     "id=userCode",
                     "id"
                  ],
                  [
                     "css=#userCode",
                     "css:finder"
                  ],
                  [
                     "xpath=//input[@id='userCode']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//input",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e7\u05d5\u05d3 \u05de\u05e9\u05ea\u05de\u05e9",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"32b2761d-a819-40e5-aba3-167a9306ab5e",
               "comment":"",
               "command":"type",
               "target":"id=userCode",
               "targets":[
                  [
                     "id=userCode",
                     "id"
                  ],
                  [
                     "css=#userCode",
                     "css:finder"
                  ],
                  [
                     "xpath=//input[@id='userCode']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//input",
                     "xpath:position"
                  ]
               ],
               "value":"vn02727",
               "name":"\u05e7\u05d5\u05d3 \u05de\u05e9\u05ea\u05de\u05e9",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"78f318cf-65ff-4324-a1bb-fd3ff0546c41",
               "comment":"",
               "command":"click",
               "target":"id=password",
               "targets":[
                  [
                     "id=password",
                     "id"
                  ],
                  [
                     "css=#password",
                     "css:finder"
                  ],
                  [
                     "xpath=//input[@id='password']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//div[2]/poalim-mm-field/div/input",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e1\u05d9\u05e1\u05de\u05d4",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"b8ee6f98-3b94-43aa-93ef-0b08c2e57c8c",
               "comment":"",
               "command":"type",
               "target":"id=password",
               "targets":[
                  [
                     "id=password",
                     "id"
                  ],
                  [
                     "css=#password",
                     "css:finder"
                  ],
                  [
                     "xpath=//input[@id='password']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//div[2]/poalim-mm-field/div/input",
                     "xpath:position"
                  ]
               ],
               "value":"mordsmi9",
               "name":"\u05e1\u05d9\u05e1\u05de\u05d4",
               "title":"\u05db\u05e0\u05d9\u05e1\u05d4 \u05dc\u05d7\u05e9\u05d1\u05d5\u05e0\u05da - \u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            },
            {
               "id":"23cfaccf-dfbe-4230-ba36-ea8c33dec81f",
               "comment":"",
               "command":"click",
               "target":"css=.red-coloring-btn",
               "targets":[
                  [
                     "css=.red-coloring-btn",
                     "css:finder"
                  ],
                  [
                     "xpath=//button[@type='submit']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//div[3]/button",
                     "xpath:position"
                  ],
                  [
                     "xpath=//button[contains(.,'\u05db\u05e0\u05d9\u05e1\u05d4')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"\u05db\u05e0\u05d9\u05e1\u05d4",
               "title":"\u05d3\u05e3 \u05d4\u05d1\u05d9\u05ea"
            },
            {
               "id":"33239645-6d08-42dd-88a7-e4e043ebbc5c",
               "comment":"",
               "command":"selectFrame",
               "target":"relative=parent",
               "targets":[
                  [
                     "relative=parent"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d3\u05e3 \u05d4\u05d1\u05d9\u05ea"
            },
            {
               "id":"32e274b7-ada2-4643-bec0-f1021c3f1e34",
               "comment":"",
               "command":"click",
               "target":"id=rb-accounts-filter-0",
               "targets":[
                  [
                     "id=rb-accounts-filter-0",
                     "id"
                  ],
                  [
                     "css=#rb-accounts-filter-0",
                     "css:finder"
                  ],
                  [
                     "xpath=//button[@id='rb-accounts-filter-0']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//section[@id='toolbar']/poalim-accounts-filter/div/button",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//poalim-accounts-filter/div/button",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05de\u05e1' : 91-15596",
               "title":"\u05d3\u05e3 \u05d4\u05d1\u05d9\u05ea"
            },
            {
               "id":"ec71af4b-be96-4a13-85cf-300069304f0b",
               "comment":"",
               "command":"click",
               "target":"css=.account-item:nth-child(3) > label",
               "targets":[
                  [
                     "css=.account-item:nth-child(3) > label",
                     "css:finder"
                  ],
                  [
                     "xpath=//ul[@id='rb-accounts-filter-0-account-list']/li[3]/label",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//li[3]/label",
                     "xpath:position"
                  ],
                  [
                     "xpath=//label[contains(.,'91-396646')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d3\u05e3 \u05d4\u05d1\u05d9\u05ea"
            },
            {
               "id":"6aeef4fd-f6aa-47f9-be59-521475362cb0",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-1",
               "targets":[
                  [
                     "id=mega-menu-1",
                     "id"
                  ],
                  [
                     "css=#mega-menu-1",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-1']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[2]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/current-account')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[2]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e2\u05d5\u05d1\u05e8\n\u05d5\u05e9\u05d1",
               "title":"\u05d3\u05e3 \u05d4\u05d1\u05d9\u05ea"
            },
            {
               "id":"0aa25f03-28f9-4f1d-a19c-5cc6488b983b",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-1",
               "targets":[
                  [
                     "id=mega-menu-1",
                     "id"
                  ],
                  [
                     "css=#mega-menu-1",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-1']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[2]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/current-account')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[2]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e2\u05d5\u05d1\u05e8\n\u05d5\u05e9\u05d1",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df"
            },
            {
               "id":"750b28c8-c876-4ea3-bc14-18ffe1b195dc",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-1",
               "targets":[
                  [
                     "id=mega-menu-1",
                     "id"
                  ],
                  [
                     "css=#mega-menu-1",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-1']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[2]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/current-account')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[2]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e2\u05d5\u05d1\u05e8\n\u05d5\u05e9\u05d1",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df"
            },
            {
               "id":"985004d0-4ed1-4153-b92a-3532dd00049d",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05e2\u05ea\u05d9\u05d3\u05d9\u05d5\u05ea",
               "targets":[
                  [
                     "linkText=\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05e2\u05ea\u05d9\u05d3\u05d9\u05d5\u05ea",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(2) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05e2\u05ea\u05d9\u05d3\u05d9\u05d5\u05ea')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='currentAccountInfoAndTransactions']/div/ul/li[2]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/current-account/future-transactions')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li[2]/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05e2\u05ea\u05d9\u05d3\u05d9\u05d5\u05ea')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05e2\u05ea\u05d9\u05d3\u05d9\u05d5\u05ea"
            },
            {
               "id":"834c5b93-f333-4478-ba71-7789a8c96ffe",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df",
               "targets":[
                  [
                     "linkText=\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(1) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='currentAccountInfoAndTransactions']/div/ul/li/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/current-account/transactions')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df"
            },
            {
               "id":"cac241e9-06fa-471e-ae00-9f12ca1746b1",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05e8\u05d9\u05db\u05d5\u05d6 \u05d9\u05ea\u05e8\u05d5\u05ea",
               "targets":[
                  [
                     "linkText=\u05e8\u05d9\u05db\u05d5\u05d6 \u05d9\u05ea\u05e8\u05d5\u05ea",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(3) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05e8\u05d9\u05db\u05d5\u05d6 \u05d9\u05ea\u05e8\u05d5\u05ea')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='currentAccountInfoAndTransactions']/div/ul/li[3]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/current-account/balances')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li[3]/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05e8\u05d9\u05db\u05d5\u05d6 \u05d9\u05ea\u05e8\u05d5\u05ea')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05e8\u05d9\u05db\u05d5\u05d6 \u05d9\u05ea\u05e8\u05d5\u05ea"
            },
            {
               "id":"9ce7bc5e-6493-43ed-8298-8163bf5e49d4",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-2",
               "targets":[
                  [
                     "id=mega-menu-2",
                     "id"
                  ],
                  [
                     "css=#mega-menu-2",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-2']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[3]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[3]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05db\u05e8\u05d8\u05d9\u05e1\u05d9\n\u05d0\u05e9\u05e8\u05d0\u05d9",
               "title":"\u05e8\u05d9\u05db\u05d5\u05d6 \u05d9\u05ea\u05e8\u05d5\u05ea"
            },
            {
               "id":"844676e2-c4cb-412d-8d51-6a2db67fd4c3",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-2",
               "targets":[
                  [
                     "id=mega-menu-2",
                     "id"
                  ],
                  [
                     "css=#mega-menu-2",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-2']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[3]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//nav/ul/li[3]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05db\u05e8\u05d8\u05d9\u05e1\u05d9\n\u05d0\u05e9\u05e8\u05d0\u05d9",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd"
            },
            {
               "id":"10f96583-c7aa-44d9-8dbf-ff9b7b910232",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-2",
               "targets":[
                  [
                     "id=mega-menu-2",
                     "id"
                  ],
                  [
                     "css=#mega-menu-2",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-2']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[3]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[3]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05db\u05e8\u05d8\u05d9\u05e1\u05d9\n\u05d0\u05e9\u05e8\u05d0\u05d9",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd"
            },
            {
               "id":"f0982d55-c986-4af6-8324-a81a3d1a526a",
               "comment":"",
               "command":"mouseOver",
               "target":"linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd",
               "targets":[
                  [
                     "linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd",
                     "linkText"
                  ],
                  [
                     "css=.active:nth-child(1) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='plasticCardsInfo']/div/ul/li/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards/current-debit')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd"
            },
            {
               "id":"d9053be8-210a-4a6c-a29f-40c10f45bec5",
               "comment":"",
               "command":"mouseOut",
               "target":"linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd",
               "targets":[
                  [
                     "linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd",
                     "linkText"
                  ],
                  [
                     "css=.active:nth-child(1) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='plasticCardsInfo']/div/ul/li/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards/current-debit')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd"
            },
            {
               "id":"a533edf3-a819-4adf-a1dd-9285a42e2161",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05d5\u05d3\u05de\u05d9\u05dd",
               "targets":[
                  [
                     "linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05d5\u05d3\u05de\u05d9\u05dd",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(2) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05d5\u05d3\u05de\u05d9\u05dd')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='plasticCardsInfo']/div/ul/li[2]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards/previous-debit')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li[2]/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05d5\u05d3\u05de\u05d9\u05dd')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05d5\u05d3\u05de\u05d9\u05dd"
            },
            {
               "id":"60fbc0bd-f55b-4acd-a29f-430aa5c6a270",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd",
               "targets":[
                  [
                     "linkText=\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(1) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='plasticCardsInfo']/div/ul/li/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/plastic-cards/current-debit')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd"
            },
            {
               "id":"1fe90b88-6b36-4895-90f0-7c12fe8b56af",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-3",
               "targets":[
                  [
                     "id=mega-menu-3",
                     "id"
                  ],
                  [
                     "css=#mega-menu-3",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-3']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[4]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/deposits-and-savings')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[4]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e4\u05d9\u05e7\u05d3\u05d5\u05e0\u05d5\u05ea\n\u05d5\u05d7\u05e1\u05db\u05d5\u05e0\u05d5\u05ea",
               "title":"\u05d7\u05d9\u05d5\u05d1\u05d9\u05dd \u05e7\u05e8\u05d5\u05d1\u05d9\u05dd"
            },
            {
               "id":"55363ba3-8de1-4147-b292-7398d076656e",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-3",
               "targets":[
                  [
                     "id=mega-menu-3",
                     "id"
                  ],
                  [
                     "css=#mega-menu-3",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-3']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[4]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/deposits-and-savings')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//nav/ul/li[4]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e4\u05d9\u05e7\u05d3\u05d5\u05e0\u05d5\u05ea\n\u05d5\u05d7\u05e1\u05db\u05d5\u05e0\u05d5\u05ea",
               "title":"\u05d4\u05e4\u05e7\u05d3\u05d4 \u05dc\u05e4\u05d9\u05e7\u05d3\u05d5\u05df"
            },
            {
               "id":"faa9e35f-51db-479d-a53e-cb1616156837",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-3",
               "targets":[
                  [
                     "id=mega-menu-3",
                     "id"
                  ],
                  [
                     "css=#mega-menu-3",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-3']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[4]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/deposits-and-savings')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[4]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e4\u05d9\u05e7\u05d3\u05d5\u05e0\u05d5\u05ea\n\u05d5\u05d7\u05e1\u05db\u05d5\u05e0\u05d5\u05ea",
               "title":"\u05d4\u05e4\u05e7\u05d3\u05d4 \u05dc\u05e4\u05d9\u05e7\u05d3\u05d5\u05df"
            },
            {
               "id":"4befc722-3c0e-4b22-9127-4d8524efe012",
               "comment":"",
               "command":"click",
               "target":"css=#depositsAndSavingsDetails-header > .btn",
               "targets":[
                  [
                     "css=#depositsAndSavingsDetails-header > .btn",
                     "css:finder"
                  ],
                  [
                     "xpath=(//button[@type='button'])[15]",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//div[@id='depositsAndSavingsDetails-header']/button",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//ngb-accordion/div/div/button",
                     "xpath:position"
                  ],
                  [
                     "xpath=//button[contains(.,'\u05de\u05d9\u05d3\u05e2')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d4\u05e4\u05e7\u05d3\u05d4 \u05dc\u05e4\u05d9\u05e7\u05d3\u05d5\u05df"
            },
            {
               "id":"6d7d00ad-86ab-463b-8854-e7ada40224c7",
               "comment":"",
               "command":"click",
               "target":"css=#depositsAndSavingsPerry-header > .btn",
               "targets":[
                  [
                     "css=#depositsAndSavingsPerry-header > .btn",
                     "css:finder"
                  ],
                  [
                     "xpath=(//button[@type='button'])[16]",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//div[@id='depositsAndSavingsPerry-header']/button",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//div[2]/div/button",
                     "xpath:position"
                  ],
                  [
                     "xpath=//button[contains(.,'\u05e4\u05e8\"\u05d9')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d4\u05e4\u05e7\u05d3\u05d4 \u05dc\u05e4\u05d9\u05e7\u05d3\u05d5\u05df"
            },
            {
               "id":"0d70e46d-cd50-42a5-8233-43b8158c32db",
               "comment":"",
               "command":"click",
               "target":"css=#depositsAndSavingsNisDeposit-header > .btn",
               "targets":[
                  [
                     "css=#depositsAndSavingsNisDeposit-header > .btn",
                     "css:finder"
                  ],
                  [
                     "xpath=(//button[@type='button'])[17]",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//div[@id='depositsAndSavingsNisDeposit-header']/button",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//ngb-accordion/div[3]/div/button",
                     "xpath:position"
                  ],
                  [
                     "xpath=//button[contains(.,'\u05e4\u05d9\u05e7\u05d3\u05d5\u05e0\u05d5\u05ea \u05e9\u05e7\u05dc\u05d9\u05d9\u05dd')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d4\u05e4\u05e7\u05d3\u05d4 \u05dc\u05e4\u05d9\u05e7\u05d3\u05d5\u05df"
            },
            {
               "id":"6be67d98-1048-4ffe-90f7-408fed35f32a",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-4",
               "targets":[
                  [
                     "id=mega-menu-4",
                     "id"
                  ],
                  [
                     "css=#mega-menu-4",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-4']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[5]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/payments')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[5]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05ea\u05e9\u05dc\u05d5\u05de\u05d9\n\u05d7\u05e9\u05d1\u05d5\u05e0\u05d5\u05ea",
               "title":"\u05d4\u05e4\u05e7\u05d3\u05d4 \u05dc\u05e4\u05d9\u05e7\u05d3\u05d5\u05df"
            },
            {
               "id":"96e58b5f-58c8-44d9-bb67-f253305e1089",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-4",
               "targets":[
                  [
                     "id=mega-menu-4",
                     "id"
                  ],
                  [
                     "css=#mega-menu-4",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-4']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[5]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/payments')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//nav/ul/li[5]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05ea\u05e9\u05dc\u05d5\u05de\u05d9\n\u05d7\u05e9\u05d1\u05d5\u05e0\u05d5\u05ea",
               "title":"\u05de\u05d4 \u05ea\u05e8\u05e6\u05d4 \u05dc\u05e9\u05dc\u05dd"
            },
            {
               "id":"1ec7bfbf-3308-4588-8531-aa42889e3fee",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-4",
               "targets":[
                  [
                     "id=mega-menu-4",
                     "id"
                  ],
                  [
                     "css=#mega-menu-4",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-4']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[5]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/payments')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[5]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05ea\u05e9\u05dc\u05d5\u05de\u05d9\n\u05d7\u05e9\u05d1\u05d5\u05e0\u05d5\u05ea",
               "title":"\u05de\u05d4 \u05ea\u05e8\u05e6\u05d4 \u05dc\u05e9\u05dc\u05dd"
            },
            {
               "id":"dd4b2b32-2c3b-40a7-84dc-503a448a69e4",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05d7\u05d1\u05e8\u05ea \u05d7\u05e9\u05de\u05dc",
               "targets":[
                  [
                     "linkText=\u05d7\u05d1\u05e8\u05ea \u05d7\u05e9\u05de\u05dc",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(1) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05d7\u05d1\u05e8\u05ea \u05d7\u05e9\u05de\u05dc')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='paymentsMoreTitle']/div/ul/li/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/payments/shoham/electricCorporation')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05d7\u05d1\u05e8\u05ea \u05d7\u05e9\u05de\u05dc')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05de\u05d4 \u05ea\u05e8\u05e6\u05d4 \u05dc\u05e9\u05dc\u05dd"
            },
            {
               "id":"09e79a91-81a0-47e7-88e6-48e26e82c7c0",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-9",
               "targets":[
                  [
                     "id=mega-menu-9",
                     "id"
                  ],
                  [
                     "css=#mega-menu-9",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-9']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[10]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/cgi-bin/poalwwwc?reqName=MainFrameSet&isCoExistence=yes&isCoExistenceReplace=no&transactionId=ShukHoon*first')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[10]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05dc\u05d0\u05ea\u05e8\n\u05e9\u05d5\u05e7 \u05d4\u05d4\u05d5\u05df",
               "title":"\u05de\u05d4 \u05ea\u05e8\u05e6\u05d4 \u05dc\u05e9\u05dc\u05dd"
            },
            {
               "id":"9780a5e8-6362-4e28-b808-a997174b240c",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-9",
               "targets":[
                  [
                     "id=mega-menu-9",
                     "id"
                  ],
                  [
                     "css=#mega-menu-9",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-9']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[10]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/cgi-bin/poalwwwc?reqName=MainFrameSet&isCoExistence=yes&isCoExistenceReplace=no&transactionId=ShukHoon*first')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[10]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05dc\u05d0\u05ea\u05e8\n\u05e9\u05d5\u05e7 \u05d4\u05d4\u05d5\u05df",
               "title":"\u05de\u05d4 \u05ea\u05e8\u05e6\u05d4 \u05dc\u05e9\u05dc\u05dd"
            },
            {
               "id":"06daf9ea-4fc7-4f30-b013-659789270ef0",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05e8\u05e9\u05d5\u05d9\u05d5\u05ea \u05de\u05e7\u05d5\u05de\u05d9\u05d5\u05ea",
               "targets":[
                  [
                     "linkText=\u05e8\u05e9\u05d5\u05d9\u05d5\u05ea \u05de\u05e7\u05d5\u05de\u05d9\u05d5\u05ea",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(2) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05e8\u05e9\u05d5\u05d9\u05d5\u05ea \u05de\u05e7\u05d5\u05de\u05d9\u05d5\u05ea')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='paymentsMoreTitle']/div/ul/li[2]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/payments/local-authority')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li[2]/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05e8\u05e9\u05d5\u05d9\u05d5\u05ea \u05de\u05e7\u05d5\u05de\u05d9\u05d5\u05ea')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05d7\u05d1\u05e8\u05ea \u05d7\u05e9\u05de\u05dc"
            },
            {
               "id":"a9b4a4c4-55fb-49ff-9f0f-019d193d6870",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-5",
               "targets":[
                  [
                     "id=mega-menu-5",
                     "id"
                  ],
                  [
                     "css=#mega-menu-5",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-5']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[6]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/credit-and-mortgage')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[6]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05d4\u05dc\u05d5\u05d5\u05d0\u05d5\u05ea\n\u05d5\u05de\u05e9\u05db\u05e0\u05ea\u05d0",
               "title":"\u05e8\u05e9\u05d5\u05d9\u05d5\u05ea \u05de\u05e7\u05d5\u05de\u05d9\u05d5\u05ea"
            },
            {
               "id":"aee05deb-9b29-4566-b77f-479c88dafada",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-5",
               "targets":[
                  [
                     "id=mega-menu-5",
                     "id"
                  ],
                  [
                     "css=#mega-menu-5",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-5']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[6]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/credit-and-mortgage')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[6]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05d4\u05dc\u05d5\u05d5\u05d0\u05d5\u05ea\n\u05d5\u05de\u05e9\u05db\u05e0\u05ea\u05d0",
               "title":"\u05d7\u05d9\u05d6\u05d5\u05e7 \u05d4\u05d6\u05d3\u05d4\u05d5\u05ea"
            },
            {
               "id":"5b3f39df-a61d-4ab3-8ffc-23dd7df85ab6",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-6",
               "targets":[
                  [
                     "id=mega-menu-6",
                     "id"
                  ],
                  [
                     "css=#mega-menu-6",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-6']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[7]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/foreign-currency')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[7]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05de\u05d8\u05d1\u05e2\n\u05d7\u05d5\u05e5",
               "title":"\u05d7\u05d9\u05d6\u05d5\u05e7 \u05d4\u05d6\u05d3\u05d4\u05d5\u05ea"
            },
            {
               "id":"7d48b9c3-9c36-42d6-84e7-8e4ba7c4f26b",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-6",
               "targets":[
                  [
                     "id=mega-menu-6",
                     "id"
                  ],
                  [
                     "css=#mega-menu-6",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-6']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[7]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/foreign-currency')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[7]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05de\u05d8\u05d1\u05e2\n\u05d7\u05d5\u05e5",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df \u05de\u05d8\"\u05d7"
            },
            {
               "id":"06915a4b-9a5e-4d42-9715-9a30cea3d947",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-6",
               "targets":[
                  [
                     "id=mega-menu-6",
                     "id"
                  ],
                  [
                     "css=#mega-menu-6",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-6']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[7]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/foreign-currency')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[7]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05de\u05d8\u05d1\u05e2\n\u05d7\u05d5\u05e5",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df \u05de\u05d8\"\u05d7"
            },
            {
               "id":"84fca122-dcd5-481f-a607-66d21ba1bb0f",
               "comment":"",
               "command":"click",
               "target":"linkText=\u05e9\u05e2\u05e8\u05d9 \u05de\u05d8\"\u05d7",
               "targets":[
                  [
                     "linkText=\u05e9\u05e2\u05e8\u05d9 \u05de\u05d8\"\u05d7",
                     "linkText"
                  ],
                  [
                     "css=.card-body li:nth-child(4) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05e9\u05e2\u05e8\u05d9 \u05de\u05d8\"\u05d7')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='foreignCurrencyDetails']/div/ul/li[4]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/foreign-currency/rates')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li[4]/a",
                     "xpath:position"
                  ],
                  [
                     "xpath=//a[contains(.,'\u05e9\u05e2\u05e8\u05d9 \u05de\u05d8\"\u05d7')]",
                     "xpath:innerText"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df \u05de\u05d8\"\u05d7"
            },
            {
               "id":"c672d9da-5efe-4497-86e6-9931c45be653",
               "comment":"",
               "command":"click",
               "target":"css=.card-body li:nth-child(1) > a",
               "targets":[
                  [
                     "css=.card-body li:nth-child(1) > a",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[contains(text(),'\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \n\u05d1\u05d7\u05e9\u05d1\u05d5\u05df \u05de\u05d8\"\u05d7')]",
                     "xpath:link"
                  ],
                  [
                     "xpath=//div[@id='foreignCurrencyDetails']/div/ul/li/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/foreign-currency/transactions')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//div[2]/div/ul/li/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df \u05de\u05d8\"\u05d7"
            },
            {
               "id":"a35d65fa-0f7f-4920-8fda-85e791b4819e",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-8",
               "targets":[
                  [
                     "id=mega-menu-8",
                     "id"
                  ],
                  [
                     "css=#mega-menu-8",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-8']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[9]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/pfm')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[9]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e0\u05d9\u05d4\u05d5\u05dc\n\u05ea\u05e7\u05e6\u05d9\u05d1",
               "title":"\u05ea\u05e0\u05d5\u05e2\u05d5\u05ea \u05d1\u05d7\u05e9\u05d1\u05d5\u05df \u05de\u05d8\"\u05d7"
            },
            {
               "id":"54225925-8ba0-4f21-9737-5aeb21e3be55",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-8",
               "targets":[
                  [
                     "id=mega-menu-8",
                     "id"
                  ],
                  [
                     "css=#mega-menu-8",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-8']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[9]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/pfm')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[9]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e0\u05d9\u05d4\u05d5\u05dc\n\u05ea\u05e7\u05e6\u05d9\u05d1",
               "title":"\u05e0\u05d9\u05d4\u05d5\u05dc \u05ea\u05e7\u05e6\u05d9\u05d1"
            },
            {
               "id":"51595855-ced6-436f-869f-0bf29687b24f",
               "comment":"",
               "command":"mouseOut",
               "target":"id=mega-menu-8",
               "targets":[
                  [
                     "id=mega-menu-8",
                     "id"
                  ],
                  [
                     "css=#mega-menu-8",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-8']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[9]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/ng-portals/rb/he/pfm')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[9]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05e0\u05d9\u05d4\u05d5\u05dc\n\u05ea\u05e7\u05e6\u05d9\u05d1",
               "title":"\u05e0\u05d9\u05d4\u05d5\u05dc \u05ea\u05e7\u05e6\u05d9\u05d1"
            },
            {
               "id":"23f0d1bf-f582-4d60-928c-4965f4662a0a",
               "comment":"",
               "command":"mouseOver",
               "target":"id=mega-menu-9",
               "targets":[
                  [
                     "id=mega-menu-9",
                     "id"
                  ],
                  [
                     "css=#mega-menu-9",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-9']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[10]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/cgi-bin/poalwwwc?reqName=MainFrameSet&isCoExistence=yes&isCoExistenceReplace=no&transactionId=ShukHoon*first')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[10]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05dc\u05d0\u05ea\u05e8\n\u05e9\u05d5\u05e7 \u05d4\u05d4\u05d5\u05df",
               "title":"\u05e0\u05d9\u05d4\u05d5\u05dc \u05ea\u05e7\u05e6\u05d9\u05d1"
            },
            {
               "id":"2273e0c6-a274-45ab-9f2c-a9511456b94c",
               "comment":"",
               "command":"click",
               "target":"id=mega-menu-9",
               "targets":[
                  [
                     "id=mega-menu-9",
                     "id"
                  ],
                  [
                     "css=#mega-menu-9",
                     "css:finder"
                  ],
                  [
                     "xpath=//a[@id='mega-menu-9']",
                     "xpath:attributes"
                  ],
                  [
                     "xpath=//nav[@id='main-nav']/ul/li[10]/a",
                     "xpath:idRelative"
                  ],
                  [
                     "xpath=//a[contains(@href, '/cgi-bin/poalwwwc?reqName=MainFrameSet&isCoExistence=yes&isCoExistenceReplace=no&transactionId=ShukHoon*first')]",
                     "xpath:href"
                  ],
                  [
                     "xpath=//li[10]/a",
                     "xpath:position"
                  ]
               ],
               "value":"",
               "name":"\u05dc\u05d0\u05ea\u05e8\n\u05e9\u05d5\u05e7 \u05d4\u05d4\u05d5\u05df",
               "title":"\u05d1\u05e0\u05e7 \u05d4\u05e4\u05d5\u05e2\u05dc\u05d9\u05dd"
            }
         ]
      }
   ],
   "suites":[
      {
         "id":"4a89d19c-7838-461e-be00-38e68c8037c5",
         "name":"Default Suite",
         "persistSession":False,
         "parallel":False,
         "timeout":300,
         "tests":[
            "f68bf018-e58a-41ca-87e9-6583d1fd3aa4"
         ]
      }
   ],
   "urls":[
      "https://www.bankhapoalim.co.il/"
   ],
   "plugins":[
      
   ]
}

for test in data["tests"]:
    for command in test["commands"]:
        print (command["name"],command["id"])
# Out:
# כניסה לחשבונך - בנק הפועלים c153076a-8beb-499c-ade7-89837b664130
#  b664752e-9eaf-4c2c-b946-e813561b79aa
# כניסה לחשבון 496273d4-f96e-4765-abdc-4b0c11999e4e
#  3d9d1a8e-576e-4c77-8339-44c909f91943
# קוד משתמש 82e1ebf4-0f4f-4d27-9299-a188f6305856
# קוד משתמש 32b2761d-a819-40e5-aba3-167a9306ab5e
# סיסמה 78f318cf-65ff-4324-a1bb-fd3ff0546c41
# סיסמה b8ee6f98-3b94-43aa-93ef-0b08c2e57c8c
# כניסה 23cfaccf-dfbe-4230-ba36-ea8c33dec81f
#  33239645-6d08-42dd-88a7-e4e043ebbc5c
# מס' : 91-15596 32e274b7-ada2-4643-bec0-f1021c3f1e34
#  ec71af4b-be96-4a13-85cf-300069304f0b
# עובר
# ושב 6aeef4fd-f6aa-47f9-be59-521475362cb0
# עובר
# ושב 0aa25f03-28f9-4f1d-a19c-5cc6488b983b
# עובר
# ושב 750b28c8-c876-4ea3-bc14-18ffe1b195dc
#  985004d0-4ed1-4153-b92a-3532dd00049d
#  834c5b93-f333-4478-ba71-7789a8c96ffe
#  cac241e9-06fa-471e-ae00-9f12ca1746b1
# כרטיסי
# אשראי 9ce7bc5e-6493-43ed-8298-8163bf5e49d4
# כרטיסי
# אשראי 844676e2-c4cb-412d-8d51-6a2db67fd4c3
# כרטיסי
# אשראי 10f96583-c7aa-44d9-8dbf-ff9b7b910232
# ...
